# %%
import pandas as pd
df = pd.read_csv('agora.csv')

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %% [markdown]
# # Standardization

# %%
 from sklearn.preprocessing import StandardScaler

# %%
s = StandardScaler()

# %%
s_fit = s.fit(df[['Marketing Spend']])

# %%
s_fit
# Out:
# StandardScaler()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df['Marketing Spend'] = s.transform(df[['Marketing Spend']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913       136897.80  471784.10    Dhaka  192261.83
# 1         1.955860       151377.59  443898.53      Ctg  191792.06
# 2         1.754364       101145.55  407934.54  Rangpur  191050.39
# 3         1.554784       118671.85  383199.62    Dhaka  182901.99
# 4         1.504937        91391.77  366168.42  Rangpur  166187.94

# %%
df.Administration = s.transform(df[['Administration']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913        1.390293  471784.10    Dhaka  192261.83
# 1         1.955860        1.708944  443898.53      Ctg  191792.06
# 2         1.754364        0.603508  407934.54  Rangpur  191050.39
# 3         1.554784        0.989202  383199.62    Dhaka  182901.99
# 4         1.504937        0.388860  366168.42  Rangpur  166187.94

# %%
df.Transport = s.fit_transform(df[['Transport']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913        1.390293   2.165287    Dhaka  192261.83
# 1         1.955860        1.708944   1.929843      Ctg  191792.06
# 2         1.754364        0.603508   1.626191  Rangpur  191050.39
# 3         1.554784        0.989202   1.417348    Dhaka  182901.99
# 4         1.504937        0.388860   1.273550  Rangpur  166187.94

# %%
df.columns
# Out:
# Index(['Marketing Spend', 'Administration', 'Transport', 'Area', 'Profit'], dtype='object')

# %%
df = df.drop(['Profit'],axis=1)

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.897913        1.390293   2.165287    Dhaka
# 1         1.955860        1.708944   1.929843      Ctg
# 2         1.754364        0.603508   1.626191  Rangpur
# 3         1.554784        0.989202   1.417348    Dhaka
# 4         1.504937        0.388860   1.273550  Rangpur

# %%
df = df.drop(['Area'],axis=1)

# %%
df.head(50)
# Out:
#     Marketing Spend  Administration  Transport
# 0          0.897913        1.390293   2.165287
# 1          1.955860        1.708944   1.929843
# 2          1.754364        0.603508   1.626191
# 3          1.554784        0.989202   1.417348
# 4          1.504937        0.388860   1.273550
# 5          1.279800        0.574220   1.245627
# 6          1.340066        1.616984  -0.739753
# 7          1.245057        1.580260   0.916470
# 8          1.030369        1.650436   0.812928
# 9          1.091819        0.769297   0.756935
# 10         0.620398        0.811438   0.116763
# 11         0.593085        0.397637   0.290555
# 12         0.443260        1.179527   0.291357
# 13         0.402078        1.359424   0.315213
# 14         1.017181        1.822714   0.347702
# 15         2.016411        1.076018   0.392142
# 16         0.094441        1.053586   0.413839
# 17         0.460720        1.570302   0.567745
# 18         0.396725        0.890259   0.671979
# ...
